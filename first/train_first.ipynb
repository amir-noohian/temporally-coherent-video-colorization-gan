# %% [markdown]
# ## In this code, we just consider GAN loss. In addition, we just use the current lineart frame to input the generator.

# %%
# !pip uninstall scipy
# !pip install scipy==1.1.0
# Out:
# Uninstalling scipy-1.1.0:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/scipy-1.1.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/scipy/*
# Proceed (y/n)? y
#   Successfully uninstalled scipy-1.1.0
# Collecting scipy==1.1.0
#   Using cached https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.19.5)
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
# Successfully installed scipy-1.1.0

# %%
import sys
import os
import numpy as np
from math import log10
from os.path import join
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
import torch.backends.cudnn as cudnn
import torchvision.transforms as transforms

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
sys.path.append('/content/gdrive/MyDrive/src_first')

# %%
from models import define_G, define_D, print_network
from data import get_training_set, get_test_set, create_iterator
from dataset import DatasetFromFolder
from loss import AdversarialLoss, StyleLoss, PerceptualLoss
from util import Progbar, stitch_images, postprocess, load

# %%
root = '/content/gdrive/MyDrive'
dataset = 'dataset'
logfile = 'trainlogs.dat'
checkpoint_path_G = False
checkpoint_path_D = False
batchSize = 16
testBatchSize = 1
nEpochs = 80
input_nc = 1
output_nc = 3
lr = 0.0001
beta1 = 0
cuda = True
threads = 0
seed = 123
L1lamb = 0
Stylelamb = 0
Contentlamb = 0
Adversariallamb = 1 # In this case, we just consider GAN loss.
ndf = 2
ngf = 2

# %%
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")

cudnn.benchmark = True

torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
print('===> Loading datasets')
root_path = root
train_set = get_training_set(join(root_path , dataset))
test_set = get_test_set(join(root_path , dataset))
# Out:
# ===> Loading datasets

# %%
training_data_loader = DataLoader(dataset=train_set, num_workers=threads, batch_size=batchSize, shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=threads, batch_size=testBatchSize, shuffle=False)

# %%
sample_iterator = create_iterator(4, test_set)

# %%
print('===> Building model')
netG = define_G(input_nc, output_nc, ngf, False, [0])
netD = define_D(input_nc + output_nc, ndf, False, [0])
# Out:
# ===> Building model

# %%
if checkpoint_path_G and checkpoint_path_D:
    load(checkpoint_path_G, checkpoint_path_D, netG, netD)

# %%
criterionGAN = AdversarialLoss()
criterionSTYLE = StyleLoss()
criterionCONTENT = PerceptualLoss()
criterionL1 = nn.L1Loss()
criterionMSE = nn.MSELoss()

# %%
# setup optimizer
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerD = optim.Adam(netD.parameters(), lr=lr * 0.1, betas=(beta1, 0.999))

# %%
print('---------- Networks initialized -------------')
print_network(netG)
print_network(netD)
print('-----------------------------------------------')
# Out:
# ---------- Networks initialized -------------
# InpaintGenerator(
#   (encoder): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(1, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (8): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (9): ReLU(inplace=True)
#   )
#   (middle): Sequential(
#     (0): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (1): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (2): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (3): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (4): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (5): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (6): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (7): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((2, 2, 2, 2))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): ReLU(inplace=True)
#     (6): ReflectionPad2d((3, 3, 3, 3))
#     (7): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   )
# )
# Total number of parameters: 10765187
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(4, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (features): Sequential(
#     (0): Conv2d(4, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1), bias=False)
#   )
# )
# Total number of parameters: 2764800
# -----------------------------------------------

# %%
real_a = torch.FloatTensor(batchSize, input_nc, 256, 256)
real_b = torch.FloatTensor(batchSize, output_nc, 256, 256)

# %%
if cuda:
    netD = netD.cuda()
    netG = netG.cuda()
    criterionGAN = criterionGAN.cuda()
    criterionL1 = criterionL1.cuda()
    critertionSTYLE = criterionSTYLE.cuda()
    criterionCONTENT = criterionCONTENT.cuda()
    criterionMSE = criterionMSE.cuda()
    real_a = real_a.cuda()
    real_b = real_b.cuda()

real_a = Variable(real_a)
real_b = Variable(real_b)

# %%
def train(epoch):

    for iteration, batch in enumerate(training_data_loader, 1):
        # forward
        real_a_cpu, real_b_cpu = batch[0], batch[1]
        with torch.no_grad():
          real_a.resize_(real_a_cpu.size()).copy_(real_a_cpu)
          real_b.resize_(real_b_cpu.size()).copy_(real_b_cpu)
        
        input_joined = real_a

        fake_b = netG(input_joined)

        ############################
        # (1) Update D network: maximize log(D(x,y)) + log(1 - D(x,G(x)))
        ###########################

        optimizerD.zero_grad()

        # train with fake
        fake_ab = torch.cat((real_a, fake_b), 1)
        pred_fake = netD.forward(fake_ab.detach())
        loss_d_fake = criterionGAN(pred_fake,False,True)

        # train with real
        real_ab = torch.cat((real_a, real_b), 1)
        pred_real = netD.forward(real_ab)
        loss_d_real = criterionGAN(pred_real, True, True) 


        # Combined loss
        loss_d = (loss_d_fake + loss_d_real) * 0.5

        loss_d.backward()

        #Discriminator parameters update every 12 iterations 
        if (iteration == 1 or iteration % 12 == 0):
            optimizerD.step()

        ############################
        # (2) Update G network: maximize log(D(x,G(x))) + L1(y,G(x))
        ##########################
        optimizerG.zero_grad()

        # First, G(A) should fake the discriminator
        fake_ab = torch.cat((real_a, fake_b), 1)
        pred_fake = netD.forward(fake_ab)
        loss_g_gan = criterionGAN(pred_fake, True, False)

        # Second, G(A) = B
        loss_g_l1 = criterionL1(fake_b, real_b) * L1lamb
        loss_g = loss_g_gan + loss_g_l1

        loss_g_style = criterionSTYLE(fake_b,real_b) * Stylelamb
        loss_g = loss_g + loss_g_style

        loss_g_content = criterionCONTENT(fake_b,real_b) * Contentlamb
        loss_g = loss_g + loss_g_content

        loss_g.backward()

        optimizerG.step()

        if (iteration % 7 == 0):
            logs = [("epoc", epoch),("iter", iteration),("Loss_G", loss_g.item()),("Loss_D", loss_d.item()), ("Loss_G_adv",loss_g_gan.item()),("Loss_G_L1",loss_g_l1.item()),("Loss_G_style",loss_g_style.item()),("Loss_G_content",loss_g_content.item()),("Loss_D_Real",loss_d_real.item()),("Loss_D_Fake",loss_d_fake.item())]
            log_train_data(logs)

        if (iteration % 7 == 0):
            sample(iteration)


        print("===> Epoch[{}]({}/{}): Loss_D: {:.4f} Loss_G: {:.4f} LossD_Fake: {:.4f} LossD_Real: {:.4f}  LossG_Adv: {:.4f} LossG_L1: {:.4f} LossG_Style {:.4f} LossG_Content {:.4f}".format(
           epoch, iteration, len(training_data_loader), loss_d, loss_g, loss_d_fake, loss_d_real, loss_g_gan, loss_g_l1, loss_g_style, loss_g_content))

# %%
def sample(iteration):
    with torch.no_grad():

        input,target,prev_frame = next(sample_iterator)
        
        if cuda:
            input = input.cuda()
            target = target.cuda()

        pred_input = input
        prediction = netG(pred_input)
        prediction = postprocess(prediction)
        input = postprocess(input)
        target = postprocess(target)

    img = stitch_images(input, target, prediction)
    samples_dir = root_path + "/samples_first"

    if not os.path.exists(samples_dir):
        os.makedirs(samples_dir)

    sample = dataset + "_" + str(epoch) + "_" + str(iteration).zfill(2) + ".jpg"
    print('\nsaving sample ' + sample + ' - learning rate: ' + str(lr))
    img.save(os.path.join(samples_dir, sample))

# %%
def log_train_data(loginfo):
    log_dir = root_path + "/logs_first"
    if not os.path.exists(log_dir):
        os.makedirs(log_dir)
    log_file = log_dir + "/" + logfile
    with open(log_file, 'a') as f:
        f.write('%s\n' % ' '.join([str(item[1]) for item in loginfo]))

# %%
def checkpoint(epoch):
    checkpoint_dir = root_path + '/checkpoint_first'
    if not os.path.exists(checkpoint_dir):
        os.makedirs(checkpoint_dir)

    net_g_model_out_path = checkpoint_dir + "/netG_weights_epoch_{}.pth".format(epoch)
    net_d_model_out_path = checkpoint_dir + "/netD_weights_epoch_{}.pth".format(epoch)

    torch.save({'generator': netG.state_dict()}, net_g_model_out_path)
    torch.save({'discriminator': netD.state_dict()}, net_d_model_out_path)
    
    print("Checkpoint saved to {}".format("checkpoint" + dataset))

# %%
for epoch in range(1, nEpochs + 1):
    train(epoch)
    checkpoint(epoch)
# Out:
# ===> Epoch[1](1/7): Loss_D: 0.6832 Loss_G: 0.7350 LossD_Fake: 0.6447 LossD_Real: 0.7217  LossG_Adv: 0.7350 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[1](2/7): Loss_D: 0.6933 Loss_G: 0.7176 LossD_Fake: 0.6665 LossD_Real: 0.7200  LossG_Adv: 0.7176 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[1](3/7): Loss_D: 0.6984 Loss_G: 0.7076 LossD_Fake: 0.6784 LossD_Real: 0.7183  LossG_Adv: 0.7076 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[1](4/7): Loss_D: 0.7026 Loss_G: 0.6959 LossD_Fake: 0.6905 LossD_Real: 0.7146  LossG_Adv: 0.6959 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[1](5/7): Loss_D: 0.7064 Loss_G: 0.6880 LossD_Fake: 0.6985 LossD_Real: 0.7142  LossG_Adv: 0.6880 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[1](6/7): Loss_D: 0.7106 Loss_G: 0.6809 LossD_Fake: 0.7058 LossD_Real: 0.7154  LossG_Adv: 0.6809 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_1_07.jpg - learning rate: 0.0001
# ===> Epoch[1](7/7): Loss_D: 0.7107 Loss_G: 0.6781 LossD_Fake: 0.7087 LossD_Real: 0.7127  LossG_Adv: 0.6781 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[2](1/7): Loss_D: 0.7144 Loss_G: 0.6812 LossD_Fake: 0.7139 LossD_Real: 0.7149  LossG_Adv: 0.6812 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[2](2/7): Loss_D: 0.7101 Loss_G: 0.6799 LossD_Fake: 0.7067 LossD_Real: 0.7134  LossG_Adv: 0.6799 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[2](3/7): Loss_D: 0.7111 Loss_G: 0.6775 LossD_Fake: 0.7093 LossD_Real: 0.7129  LossG_Adv: 0.6775 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[2](4/7): Loss_D: 0.7122 Loss_G: 0.6755 LossD_Fake: 0.7113 LossD_Real: 0.7131  LossG_Adv: 0.6755 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[2](5/7): Loss_D: 0.7128 Loss_G: 0.6753 LossD_Fake: 0.7115 LossD_Real: 0.7142  LossG_Adv: 0.6753 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[2](6/7): Loss_D: 0.7133 Loss_G: 0.6738 LossD_Fake: 0.7130 LossD_Real: 0.7135  LossG_Adv: 0.6738 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_2_07.jpg - learning rate: 0.0001
# ===> Epoch[2](7/7): Loss_D: 0.7140 Loss_G: 0.6728 LossD_Fake: 0.7140 LossD_Real: 0.7140  LossG_Adv: 0.6728 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[3](1/7): Loss_D: 0.7140 Loss_G: 0.6812 LossD_Fake: 0.7149 LossD_Real: 0.7132  LossG_Adv: 0.6812 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[3](2/7): Loss_D: 0.7105 Loss_G: 0.6805 LossD_Fake: 0.7060 LossD_Real: 0.7150  LossG_Adv: 0.6805 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[3](3/7): Loss_D: 0.7100 Loss_G: 0.6805 LossD_Fake: 0.7061 LossD_Real: 0.7139  LossG_Adv: 0.6805 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[3](4/7): Loss_D: 0.7108 Loss_G: 0.6794 LossD_Fake: 0.7071 LossD_Real: 0.7145  LossG_Adv: 0.6794 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[3](5/7): Loss_D: 0.7102 Loss_G: 0.6795 LossD_Fake: 0.7071 LossD_Real: 0.7134  LossG_Adv: 0.6795 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[3](6/7): Loss_D: 0.7106 Loss_G: 0.6788 LossD_Fake: 0.7077 LossD_Real: 0.7134  LossG_Adv: 0.6788 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_3_07.jpg - learning rate: 0.0001
# ===> Epoch[3](7/7): Loss_D: 0.7122 Loss_G: 0.6783 LossD_Fake: 0.7083 LossD_Real: 0.7161  LossG_Adv: 0.6783 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[4](1/7): Loss_D: 0.7114 Loss_G: 0.6857 LossD_Fake: 0.7084 LossD_Real: 0.7144  LossG_Adv: 0.6857 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[4](2/7): Loss_D: 0.7075 Loss_G: 0.6854 LossD_Fake: 0.7010 LossD_Real: 0.7140  LossG_Adv: 0.6854 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[4](3/7): Loss_D: 0.7072 Loss_G: 0.6853 LossD_Fake: 0.7011 LossD_Real: 0.7132  LossG_Adv: 0.6853 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[4](4/7): Loss_D: 0.7082 Loss_G: 0.6849 LossD_Fake: 0.7015 LossD_Real: 0.7149  LossG_Adv: 0.6849 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[4](5/7): Loss_D: 0.7083 Loss_G: 0.6845 LossD_Fake: 0.7019 LossD_Real: 0.7147  LossG_Adv: 0.6845 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[4](6/7): Loss_D: 0.7089 Loss_G: 0.6842 LossD_Fake: 0.7022 LossD_Real: 0.7155  LossG_Adv: 0.6842 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_4_07.jpg - learning rate: 0.0001
# ===> Epoch[4](7/7): Loss_D: 0.7075 Loss_G: 0.6842 LossD_Fake: 0.7022 LossD_Real: 0.7128  LossG_Adv: 0.6842 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[5](1/7): Loss_D: 0.7091 Loss_G: 0.6913 LossD_Fake: 0.7021 LossD_Real: 0.7161  LossG_Adv: 0.6913 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[5](2/7): Loss_D: 0.7052 Loss_G: 0.6906 LossD_Fake: 0.6957 LossD_Real: 0.7146  LossG_Adv: 0.6906 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[5](3/7): Loss_D: 0.7054 Loss_G: 0.6902 LossD_Fake: 0.6962 LossD_Real: 0.7145  LossG_Adv: 0.6902 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[5](4/7): Loss_D: 0.7047 Loss_G: 0.6902 LossD_Fake: 0.6961 LossD_Real: 0.7133  LossG_Adv: 0.6902 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[5](5/7): Loss_D: 0.7058 Loss_G: 0.6898 LossD_Fake: 0.6965 LossD_Real: 0.7150  LossG_Adv: 0.6898 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[5](6/7): Loss_D: 0.7054 Loss_G: 0.6897 LossD_Fake: 0.6967 LossD_Real: 0.7142  LossG_Adv: 0.6897 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_5_07.jpg - learning rate: 0.0001
# ===> Epoch[5](7/7): Loss_D: 0.7055 Loss_G: 0.6900 LossD_Fake: 0.6964 LossD_Real: 0.7146  LossG_Adv: 0.6900 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[6](1/7): Loss_D: 0.7054 Loss_G: 0.6950 LossD_Fake: 0.6968 LossD_Real: 0.7140  LossG_Adv: 0.6950 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[6](2/7): Loss_D: 0.7028 Loss_G: 0.6948 LossD_Fake: 0.6915 LossD_Real: 0.7140  LossG_Adv: 0.6948 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[6](3/7): Loss_D: 0.7037 Loss_G: 0.6943 LossD_Fake: 0.6920 LossD_Real: 0.7154  LossG_Adv: 0.6943 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[6](4/7): Loss_D: 0.7035 Loss_G: 0.6935 LossD_Fake: 0.6929 LossD_Real: 0.7142  LossG_Adv: 0.6935 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[6](5/7): Loss_D: 0.7037 Loss_G: 0.6926 LossD_Fake: 0.6937 LossD_Real: 0.7137  LossG_Adv: 0.6926 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[6](6/7): Loss_D: 0.7044 Loss_G: 0.6919 LossD_Fake: 0.6945 LossD_Real: 0.7143  LossG_Adv: 0.6919 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_6_07.jpg - learning rate: 0.0001
# ===> Epoch[6](7/7): Loss_D: 0.7045 Loss_G: 0.6926 LossD_Fake: 0.6937 LossD_Real: 0.7152  LossG_Adv: 0.6926 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[7](1/7): Loss_D: 0.7052 Loss_G: 0.6946 LossD_Fake: 0.6951 LossD_Real: 0.7152  LossG_Adv: 0.6946 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[7](2/7): Loss_D: 0.7024 Loss_G: 0.6930 LossD_Fake: 0.6933 LossD_Real: 0.7115  LossG_Adv: 0.6930 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[7](3/7): Loss_D: 0.7034 Loss_G: 0.6924 LossD_Fake: 0.6939 LossD_Real: 0.7129  LossG_Adv: 0.6924 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[7](4/7): Loss_D: 0.7032 Loss_G: 0.6918 LossD_Fake: 0.6946 LossD_Real: 0.7118  LossG_Adv: 0.6918 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[7](5/7): Loss_D: 0.7037 Loss_G: 0.6910 LossD_Fake: 0.6954 LossD_Real: 0.7120  LossG_Adv: 0.6910 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[7](6/7): Loss_D: 0.7042 Loss_G: 0.6902 LossD_Fake: 0.6962 LossD_Real: 0.7122  LossG_Adv: 0.6902 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_7_07.jpg - learning rate: 0.0001
# ===> Epoch[7](7/7): Loss_D: 0.7041 Loss_G: 0.6902 LossD_Fake: 0.6962 LossD_Real: 0.7121  LossG_Adv: 0.6902 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[8](1/7): Loss_D: 0.7059 Loss_G: 0.6897 LossD_Fake: 0.6988 LossD_Real: 0.7131  LossG_Adv: 0.6897 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[8](2/7): Loss_D: 0.7035 Loss_G: 0.6888 LossD_Fake: 0.6976 LossD_Real: 0.7095  LossG_Adv: 0.6888 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[8](3/7): Loss_D: 0.7047 Loss_G: 0.6871 LossD_Fake: 0.6993 LossD_Real: 0.7101  LossG_Adv: 0.6871 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[8](4/7): Loss_D: 0.7052 Loss_G: 0.6860 LossD_Fake: 0.7005 LossD_Real: 0.7100  LossG_Adv: 0.6860 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[8](5/7): Loss_D: 0.7047 Loss_G: 0.6870 LossD_Fake: 0.6995 LossD_Real: 0.7100  LossG_Adv: 0.6870 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[8](6/7): Loss_D: 0.7069 Loss_G: 0.6827 LossD_Fake: 0.7038 LossD_Real: 0.7099  LossG_Adv: 0.6827 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_8_07.jpg - learning rate: 0.0001
# ===> Epoch[8](7/7): Loss_D: 0.7077 Loss_G: 0.6808 LossD_Fake: 0.7058 LossD_Real: 0.7096  LossG_Adv: 0.6808 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[9](1/7): Loss_D: 0.7099 Loss_G: 0.6813 LossD_Fake: 0.7104 LossD_Real: 0.7093  LossG_Adv: 0.6813 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[9](2/7): Loss_D: 0.7070 Loss_G: 0.6817 LossD_Fake: 0.7049 LossD_Real: 0.7092  LossG_Adv: 0.6817 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[9](3/7): Loss_D: 0.7087 Loss_G: 0.6781 LossD_Fake: 0.7085 LossD_Real: 0.7088  LossG_Adv: 0.6781 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[9](4/7): Loss_D: 0.7083 Loss_G: 0.6786 LossD_Fake: 0.7081 LossD_Real: 0.7085  LossG_Adv: 0.6786 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[9](5/7): Loss_D: 0.7094 Loss_G: 0.6768 LossD_Fake: 0.7099 LossD_Real: 0.7089  LossG_Adv: 0.6768 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[9](6/7): Loss_D: 0.7099 Loss_G: 0.6759 LossD_Fake: 0.7108 LossD_Real: 0.7090  LossG_Adv: 0.6759 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_9_07.jpg - learning rate: 0.0001
# ===> Epoch[9](7/7): Loss_D: 0.7096 Loss_G: 0.6766 LossD_Fake: 0.7101 LossD_Real: 0.7091  LossG_Adv: 0.6766 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[10](1/7): Loss_D: 0.7106 Loss_G: 0.6816 LossD_Fake: 0.7124 LossD_Real: 0.7088  LossG_Adv: 0.6816 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[10](2/7): Loss_D: 0.7079 Loss_G: 0.6790 LossD_Fake: 0.7076 LossD_Real: 0.7083  LossG_Adv: 0.6790 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[10](3/7): Loss_D: 0.7075 Loss_G: 0.6802 LossD_Fake: 0.7064 LossD_Real: 0.7086  LossG_Adv: 0.6802 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[10](4/7): Loss_D: 0.7076 Loss_G: 0.6798 LossD_Fake: 0.7067 LossD_Real: 0.7085  LossG_Adv: 0.6798 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[10](5/7): Loss_D: 0.7091 Loss_G: 0.6767 LossD_Fake: 0.7099 LossD_Real: 0.7083  LossG_Adv: 0.6767 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[10](6/7): Loss_D: 0.7091 Loss_G: 0.6771 LossD_Fake: 0.7096 LossD_Real: 0.7085  LossG_Adv: 0.6771 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_10_07.jpg - learning rate: 0.0001
# ===> Epoch[10](7/7): Loss_D: 0.7102 Loss_G: 0.6751 LossD_Fake: 0.7116 LossD_Real: 0.7088  LossG_Adv: 0.6751 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[11](1/7): Loss_D: 0.7108 Loss_G: 0.6815 LossD_Fake: 0.7134 LossD_Real: 0.7082  LossG_Adv: 0.6815 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[11](2/7): Loss_D: 0.7066 Loss_G: 0.6809 LossD_Fake: 0.7056 LossD_Real: 0.7075  LossG_Adv: 0.6809 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[11](3/7): Loss_D: 0.7070 Loss_G: 0.6801 LossD_Fake: 0.7064 LossD_Real: 0.7076  LossG_Adv: 0.6801 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[11](4/7): Loss_D: 0.7070 Loss_G: 0.6804 LossD_Fake: 0.7061 LossD_Real: 0.7080  LossG_Adv: 0.6804 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[11](5/7): Loss_D: 0.7073 Loss_G: 0.6799 LossD_Fake: 0.7067 LossD_Real: 0.7079  LossG_Adv: 0.6799 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[11](6/7): Loss_D: 0.7078 Loss_G: 0.6790 LossD_Fake: 0.7076 LossD_Real: 0.7080  LossG_Adv: 0.6790 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_11_07.jpg - learning rate: 0.0001
# ===> Epoch[11](7/7): Loss_D: 0.7082 Loss_G: 0.6778 LossD_Fake: 0.7088 LossD_Real: 0.7076  LossG_Adv: 0.6778 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[12](1/7): Loss_D: 0.7087 Loss_G: 0.6847 LossD_Fake: 0.7094 LossD_Real: 0.7080  LossG_Adv: 0.6847 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[12](2/7): Loss_D: 0.7050 Loss_G: 0.6845 LossD_Fake: 0.7019 LossD_Real: 0.7081  LossG_Adv: 0.6845 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[12](3/7): Loss_D: 0.7058 Loss_G: 0.6833 LossD_Fake: 0.7031 LossD_Real: 0.7085  LossG_Adv: 0.6833 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[12](4/7): Loss_D: 0.7059 Loss_G: 0.6826 LossD_Fake: 0.7039 LossD_Real: 0.7080  LossG_Adv: 0.6826 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[12](5/7): Loss_D: 0.7063 Loss_G: 0.6818 LossD_Fake: 0.7047 LossD_Real: 0.7080  LossG_Adv: 0.6818 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[12](6/7): Loss_D: 0.7065 Loss_G: 0.6814 LossD_Fake: 0.7051 LossD_Real: 0.7079  LossG_Adv: 0.6814 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_12_07.jpg - learning rate: 0.0001
# ===> Epoch[12](7/7): Loss_D: 0.7070 Loss_G: 0.6808 LossD_Fake: 0.7057 LossD_Real: 0.7082  LossG_Adv: 0.6808 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[13](1/7): Loss_D: 0.7073 Loss_G: 0.6852 LossD_Fake: 0.7068 LossD_Real: 0.7078  LossG_Adv: 0.6852 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[13](2/7): Loss_D: 0.7045 Loss_G: 0.6846 LossD_Fake: 0.7018 LossD_Real: 0.7072  LossG_Adv: 0.6846 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[13](3/7): Loss_D: 0.7046 Loss_G: 0.6842 LossD_Fake: 0.7022 LossD_Real: 0.7069  LossG_Adv: 0.6842 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[13](4/7): Loss_D: 0.7044 Loss_G: 0.6841 LossD_Fake: 0.7023 LossD_Real: 0.7065  LossG_Adv: 0.6841 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[13](5/7): Loss_D: 0.7052 Loss_G: 0.6834 LossD_Fake: 0.7030 LossD_Real: 0.7073  LossG_Adv: 0.6834 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[13](6/7): Loss_D: 0.7051 Loss_G: 0.6830 LossD_Fake: 0.7034 LossD_Real: 0.7068  LossG_Adv: 0.6830 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_13_07.jpg - learning rate: 0.0001
# ===> Epoch[13](7/7): Loss_D: 0.7058 Loss_G: 0.6817 LossD_Fake: 0.7048 LossD_Real: 0.7068  LossG_Adv: 0.6817 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[14](1/7): Loss_D: 0.7059 Loss_G: 0.6864 LossD_Fake: 0.7049 LossD_Real: 0.7068  LossG_Adv: 0.6864 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[14](2/7): Loss_D: 0.7034 Loss_G: 0.6854 LossD_Fake: 0.7011 LossD_Real: 0.7057  LossG_Adv: 0.6854 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[14](3/7): Loss_D: 0.7044 Loss_G: 0.6838 LossD_Fake: 0.7027 LossD_Real: 0.7062  LossG_Adv: 0.6838 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[14](4/7): Loss_D: 0.7051 Loss_G: 0.6821 LossD_Fake: 0.7045 LossD_Real: 0.7057  LossG_Adv: 0.6821 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[14](5/7): Loss_D: 0.7063 Loss_G: 0.6801 LossD_Fake: 0.7065 LossD_Real: 0.7060  LossG_Adv: 0.6801 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[14](6/7): Loss_D: 0.7067 Loss_G: 0.6790 LossD_Fake: 0.7076 LossD_Real: 0.7058  LossG_Adv: 0.6790 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_14_07.jpg - learning rate: 0.0001
# ===> Epoch[14](7/7): Loss_D: 0.7083 Loss_G: 0.6765 LossD_Fake: 0.7102 LossD_Real: 0.7064  LossG_Adv: 0.6765 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[15](1/7): Loss_D: 0.7087 Loss_G: 0.6817 LossD_Fake: 0.7117 LossD_Real: 0.7057  LossG_Adv: 0.6817 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[15](2/7): Loss_D: 0.7080 Loss_G: 0.6768 LossD_Fake: 0.7100 LossD_Real: 0.7060  LossG_Adv: 0.6768 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[15](3/7): Loss_D: 0.7074 Loss_G: 0.6785 LossD_Fake: 0.7082 LossD_Real: 0.7066  LossG_Adv: 0.6785 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[15](4/7): Loss_D: 0.7104 Loss_G: 0.6726 LossD_Fake: 0.7144 LossD_Real: 0.7064  LossG_Adv: 0.6726 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[15](5/7): Loss_D: 0.7085 Loss_G: 0.6766 LossD_Fake: 0.7104 LossD_Real: 0.7065  LossG_Adv: 0.6766 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[15](6/7): Loss_D: 0.7110 Loss_G: 0.6716 LossD_Fake: 0.7154 LossD_Real: 0.7065  LossG_Adv: 0.6716 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_15_07.jpg - learning rate: 0.0001
# ===> Epoch[15](7/7): Loss_D: 0.7120 Loss_G: 0.6700 LossD_Fake: 0.7172 LossD_Real: 0.7068  LossG_Adv: 0.6700 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[16](1/7): Loss_D: 0.7136 Loss_G: 0.6737 LossD_Fake: 0.7210 LossD_Real: 0.7061  LossG_Adv: 0.6737 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[16](2/7): Loss_D: 0.7128 Loss_G: 0.6681 LossD_Fake: 0.7190 LossD_Real: 0.7066  LossG_Adv: 0.6681 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[16](3/7): Loss_D: 0.7134 Loss_G: 0.6674 LossD_Fake: 0.7198 LossD_Real: 0.7070  LossG_Adv: 0.6674 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[16](4/7): Loss_D: 0.7121 Loss_G: 0.6699 LossD_Fake: 0.7172 LossD_Real: 0.7070  LossG_Adv: 0.6699 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[16](5/7): Loss_D: 0.7153 Loss_G: 0.6636 LossD_Fake: 0.7237 LossD_Real: 0.7070  LossG_Adv: 0.6636 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[16](6/7): Loss_D: 0.7143 Loss_G: 0.6655 LossD_Fake: 0.7219 LossD_Real: 0.7067  LossG_Adv: 0.6655 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_16_07.jpg - learning rate: 0.0001
# ===> Epoch[16](7/7): Loss_D: 0.7152 Loss_G: 0.6632 LossD_Fake: 0.7242 LossD_Real: 0.7061  LossG_Adv: 0.6632 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[17](1/7): Loss_D: 0.7172 Loss_G: 0.6699 LossD_Fake: 0.7271 LossD_Real: 0.7073  LossG_Adv: 0.6699 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[17](2/7): Loss_D: 0.7138 Loss_G: 0.6668 LossD_Fake: 0.7203 LossD_Real: 0.7074  LossG_Adv: 0.6668 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[17](3/7): Loss_D: 0.7142 Loss_G: 0.6655 LossD_Fake: 0.7216 LossD_Real: 0.7069  LossG_Adv: 0.6655 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[17](4/7): Loss_D: 0.7140 Loss_G: 0.6660 LossD_Fake: 0.7211 LossD_Real: 0.7069  LossG_Adv: 0.6660 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[17](5/7): Loss_D: 0.7154 Loss_G: 0.6640 LossD_Fake: 0.7232 LossD_Real: 0.7076  LossG_Adv: 0.6640 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[17](6/7): Loss_D: 0.7150 Loss_G: 0.6643 LossD_Fake: 0.7229 LossD_Real: 0.7072  LossG_Adv: 0.6643 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_17_07.jpg - learning rate: 0.0001
# ===> Epoch[17](7/7): Loss_D: 0.7157 Loss_G: 0.6629 LossD_Fake: 0.7244 LossD_Real: 0.7070  LossG_Adv: 0.6629 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[18](1/7): Loss_D: 0.7162 Loss_G: 0.6714 LossD_Fake: 0.7248 LossD_Real: 0.7076  LossG_Adv: 0.6714 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[18](2/7): Loss_D: 0.7115 Loss_G: 0.6707 LossD_Fake: 0.7161 LossD_Real: 0.7069  LossG_Adv: 0.6707 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[18](3/7): Loss_D: 0.7114 Loss_G: 0.6709 LossD_Fake: 0.7160 LossD_Real: 0.7068  LossG_Adv: 0.6709 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[18](4/7): Loss_D: 0.7117 Loss_G: 0.6701 LossD_Fake: 0.7168 LossD_Real: 0.7067  LossG_Adv: 0.6701 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[18](5/7): Loss_D: 0.7116 Loss_G: 0.6703 LossD_Fake: 0.7166 LossD_Real: 0.7066  LossG_Adv: 0.6703 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[18](6/7): Loss_D: 0.7123 Loss_G: 0.6692 LossD_Fake: 0.7177 LossD_Real: 0.7068  LossG_Adv: 0.6692 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_18_07.jpg - learning rate: 0.0001
# ===> Epoch[18](7/7): Loss_D: 0.7120 Loss_G: 0.6689 LossD_Fake: 0.7180 LossD_Real: 0.7060  LossG_Adv: 0.6689 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[19](1/7): Loss_D: 0.7124 Loss_G: 0.6765 LossD_Fake: 0.7181 LossD_Real: 0.7067  LossG_Adv: 0.6765 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[19](2/7): Loss_D: 0.7087 Loss_G: 0.6761 LossD_Fake: 0.7105 LossD_Real: 0.7068  LossG_Adv: 0.6761 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[19](3/7): Loss_D: 0.7088 Loss_G: 0.6759 LossD_Fake: 0.7108 LossD_Real: 0.7068  LossG_Adv: 0.6759 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[19](4/7): Loss_D: 0.7087 Loss_G: 0.6758 LossD_Fake: 0.7108 LossD_Real: 0.7066  LossG_Adv: 0.6758 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[19](5/7): Loss_D: 0.7088 Loss_G: 0.6755 LossD_Fake: 0.7112 LossD_Real: 0.7065  LossG_Adv: 0.6755 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[19](6/7): Loss_D: 0.7090 Loss_G: 0.6750 LossD_Fake: 0.7117 LossD_Real: 0.7063  LossG_Adv: 0.6750 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_19_07.jpg - learning rate: 0.0001
# ===> Epoch[19](7/7): Loss_D: 0.7095 Loss_G: 0.6747 LossD_Fake: 0.7120 LossD_Real: 0.7070  LossG_Adv: 0.6747 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[20](1/7): Loss_D: 0.7094 Loss_G: 0.6816 LossD_Fake: 0.7122 LossD_Real: 0.7066  LossG_Adv: 0.6816 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[20](2/7): Loss_D: 0.7063 Loss_G: 0.6813 LossD_Fake: 0.7052 LossD_Real: 0.7073  LossG_Adv: 0.6813 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[20](3/7): Loss_D: 0.7065 Loss_G: 0.6805 LossD_Fake: 0.7060 LossD_Real: 0.7070  LossG_Adv: 0.6805 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[20](4/7): Loss_D: 0.7068 Loss_G: 0.6801 LossD_Fake: 0.7064 LossD_Real: 0.7073  LossG_Adv: 0.6801 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[20](5/7): Loss_D: 0.7062 Loss_G: 0.6803 LossD_Fake: 0.7063 LossD_Real: 0.7062  LossG_Adv: 0.6803 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[20](6/7): Loss_D: 0.7065 Loss_G: 0.6808 LossD_Fake: 0.7057 LossD_Real: 0.7073  LossG_Adv: 0.6808 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_20_07.jpg - learning rate: 0.0001
# ===> Epoch[20](7/7): Loss_D: 0.7064 Loss_G: 0.6792 LossD_Fake: 0.7074 LossD_Real: 0.7054  LossG_Adv: 0.6792 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[21](1/7): Loss_D: 0.7075 Loss_G: 0.6847 LossD_Fake: 0.7081 LossD_Real: 0.7069  LossG_Adv: 0.6847 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[21](2/7): Loss_D: 0.7045 Loss_G: 0.6836 LossD_Fake: 0.7029 LossD_Real: 0.7061  LossG_Adv: 0.6836 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[21](3/7): Loss_D: 0.7057 Loss_G: 0.6829 LossD_Fake: 0.7036 LossD_Real: 0.7077  LossG_Adv: 0.6829 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[21](4/7): Loss_D: 0.7057 Loss_G: 0.6817 LossD_Fake: 0.7048 LossD_Real: 0.7065  LossG_Adv: 0.6817 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[21](5/7): Loss_D: 0.7059 Loss_G: 0.6811 LossD_Fake: 0.7054 LossD_Real: 0.7065  LossG_Adv: 0.6811 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[21](6/7): Loss_D: 0.7071 Loss_G: 0.6794 LossD_Fake: 0.7072 LossD_Real: 0.7070  LossG_Adv: 0.6794 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_21_07.jpg - learning rate: 0.0001
# ===> Epoch[21](7/7): Loss_D: 0.7084 Loss_G: 0.6777 LossD_Fake: 0.7089 LossD_Real: 0.7078  LossG_Adv: 0.6777 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[22](1/7): Loss_D: 0.7086 Loss_G: 0.6824 LossD_Fake: 0.7102 LossD_Real: 0.7070  LossG_Adv: 0.6824 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[22](2/7): Loss_D: 0.7054 Loss_G: 0.6812 LossD_Fake: 0.7053 LossD_Real: 0.7056  LossG_Adv: 0.6812 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[22](3/7): Loss_D: 0.7062 Loss_G: 0.6793 LossD_Fake: 0.7072 LossD_Real: 0.7051  LossG_Adv: 0.6793 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[22](4/7): Loss_D: 0.7078 Loss_G: 0.6773 LossD_Fake: 0.7093 LossD_Real: 0.7062  LossG_Adv: 0.6773 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[22](5/7): Loss_D: 0.7077 Loss_G: 0.6765 LossD_Fake: 0.7102 LossD_Real: 0.7053  LossG_Adv: 0.6765 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[22](6/7): Loss_D: 0.7109 Loss_G: 0.6709 LossD_Fake: 0.7159 LossD_Real: 0.7059  LossG_Adv: 0.6709 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_22_07.jpg - learning rate: 0.0001
# ===> Epoch[22](7/7): Loss_D: 0.7118 Loss_G: 0.6685 LossD_Fake: 0.7185 LossD_Real: 0.7051  LossG_Adv: 0.6685 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[23](1/7): Loss_D: 0.7134 Loss_G: 0.6750 LossD_Fake: 0.7212 LossD_Real: 0.7057  LossG_Adv: 0.6750 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[23](2/7): Loss_D: 0.7095 Loss_G: 0.6729 LossD_Fake: 0.7139 LossD_Real: 0.7051  LossG_Adv: 0.6729 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[23](3/7): Loss_D: 0.7102 Loss_G: 0.6711 LossD_Fake: 0.7158 LossD_Real: 0.7045  LossG_Adv: 0.6711 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[23](4/7): Loss_D: 0.7109 Loss_G: 0.6696 LossD_Fake: 0.7174 LossD_Real: 0.7045  LossG_Adv: 0.6696 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[23](5/7): Loss_D: 0.7116 Loss_G: 0.6690 LossD_Fake: 0.7180 LossD_Real: 0.7053  LossG_Adv: 0.6690 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[23](6/7): Loss_D: 0.7123 Loss_G: 0.6675 LossD_Fake: 0.7195 LossD_Real: 0.7051  LossG_Adv: 0.6675 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_23_07.jpg - learning rate: 0.0001
# ===> Epoch[23](7/7): Loss_D: 0.7126 Loss_G: 0.6665 LossD_Fake: 0.7206 LossD_Real: 0.7047  LossG_Adv: 0.6665 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[24](1/7): Loss_D: 0.7130 Loss_G: 0.6763 LossD_Fake: 0.7211 LossD_Real: 0.7049  LossG_Adv: 0.6763 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[24](2/7): Loss_D: 0.7080 Loss_G: 0.6754 LossD_Fake: 0.7113 LossD_Real: 0.7047  LossG_Adv: 0.6754 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[24](3/7): Loss_D: 0.7086 Loss_G: 0.6746 LossD_Fake: 0.7121 LossD_Real: 0.7050  LossG_Adv: 0.6746 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[24](4/7): Loss_D: 0.7092 Loss_G: 0.6734 LossD_Fake: 0.7134 LossD_Real: 0.7050  LossG_Adv: 0.6734 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[24](5/7): Loss_D: 0.7098 Loss_G: 0.6726 LossD_Fake: 0.7142 LossD_Real: 0.7054  LossG_Adv: 0.6726 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[24](6/7): Loss_D: 0.7101 Loss_G: 0.6715 LossD_Fake: 0.7153 LossD_Real: 0.7049  LossG_Adv: 0.6715 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_24_07.jpg - learning rate: 0.0001
# ===> Epoch[24](7/7): Loss_D: 0.7100 Loss_G: 0.6711 LossD_Fake: 0.7158 LossD_Real: 0.7042  LossG_Adv: 0.6711 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[25](1/7): Loss_D: 0.7105 Loss_G: 0.6781 LossD_Fake: 0.7161 LossD_Real: 0.7048  LossG_Adv: 0.6781 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[25](2/7): Loss_D: 0.7068 Loss_G: 0.6772 LossD_Fake: 0.7094 LossD_Real: 0.7043  LossG_Adv: 0.6772 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[25](3/7): Loss_D: 0.7071 Loss_G: 0.6767 LossD_Fake: 0.7100 LossD_Real: 0.7042  LossG_Adv: 0.6767 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[25](4/7): Loss_D: 0.7077 Loss_G: 0.6754 LossD_Fake: 0.7113 LossD_Real: 0.7041  LossG_Adv: 0.6754 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[25](5/7): Loss_D: 0.7079 Loss_G: 0.6755 LossD_Fake: 0.7112 LossD_Real: 0.7045  LossG_Adv: 0.6755 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[25](6/7): Loss_D: 0.7082 Loss_G: 0.6746 LossD_Fake: 0.7121 LossD_Real: 0.7042  LossG_Adv: 0.6746 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_25_07.jpg - learning rate: 0.0001
# ===> Epoch[25](7/7): Loss_D: 0.7085 Loss_G: 0.6740 LossD_Fake: 0.7127 LossD_Real: 0.7044  LossG_Adv: 0.6740 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[26](1/7): Loss_D: 0.7085 Loss_G: 0.6796 LossD_Fake: 0.7128 LossD_Real: 0.7042  LossG_Adv: 0.6796 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[26](2/7): Loss_D: 0.7057 Loss_G: 0.6789 LossD_Fake: 0.7077 LossD_Real: 0.7038  LossG_Adv: 0.6789 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[26](3/7): Loss_D: 0.7058 Loss_G: 0.6783 LossD_Fake: 0.7083 LossD_Real: 0.7033  LossG_Adv: 0.6783 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[26](4/7): Loss_D: 0.7058 Loss_G: 0.6782 LossD_Fake: 0.7084 LossD_Real: 0.7032  LossG_Adv: 0.6782 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[26](5/7): Loss_D: 0.7064 Loss_G: 0.6776 LossD_Fake: 0.7090 LossD_Real: 0.7037  LossG_Adv: 0.6776 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[26](6/7): Loss_D: 0.7063 Loss_G: 0.6775 LossD_Fake: 0.7091 LossD_Real: 0.7035  LossG_Adv: 0.6775 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_26_07.jpg - learning rate: 0.0001
# ===> Epoch[26](7/7): Loss_D: 0.7064 Loss_G: 0.6770 LossD_Fake: 0.7096 LossD_Real: 0.7031  LossG_Adv: 0.6770 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[27](1/7): Loss_D: 0.7068 Loss_G: 0.6818 LossD_Fake: 0.7100 LossD_Real: 0.7035  LossG_Adv: 0.6818 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[27](2/7): Loss_D: 0.7041 Loss_G: 0.6814 LossD_Fake: 0.7051 LossD_Real: 0.7032  LossG_Adv: 0.6814 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[27](3/7): Loss_D: 0.7044 Loss_G: 0.6809 LossD_Fake: 0.7056 LossD_Real: 0.7032  LossG_Adv: 0.6809 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[27](4/7): Loss_D: 0.7045 Loss_G: 0.6806 LossD_Fake: 0.7059 LossD_Real: 0.7031  LossG_Adv: 0.6806 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[27](5/7): Loss_D: 0.7048 Loss_G: 0.6800 LossD_Fake: 0.7066 LossD_Real: 0.7031  LossG_Adv: 0.6800 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[27](6/7): Loss_D: 0.7051 Loss_G: 0.6793 LossD_Fake: 0.7073 LossD_Real: 0.7030  LossG_Adv: 0.6793 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_27_07.jpg - learning rate: 0.0001
# ===> Epoch[27](7/7): Loss_D: 0.7060 Loss_G: 0.6786 LossD_Fake: 0.7080 LossD_Real: 0.7039  LossG_Adv: 0.6786 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[28](1/7): Loss_D: 0.7058 Loss_G: 0.6824 LossD_Fake: 0.7080 LossD_Real: 0.7035  LossG_Adv: 0.6824 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[28](2/7): Loss_D: 0.7034 Loss_G: 0.6816 LossD_Fake: 0.7049 LossD_Real: 0.7020  LossG_Adv: 0.6816 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[28](3/7): Loss_D: 0.7037 Loss_G: 0.6810 LossD_Fake: 0.7056 LossD_Real: 0.7019  LossG_Adv: 0.6810 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[28](4/7): Loss_D: 0.7040 Loss_G: 0.6805 LossD_Fake: 0.7061 LossD_Real: 0.7018  LossG_Adv: 0.6805 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[28](5/7): Loss_D: 0.7041 Loss_G: 0.6801 LossD_Fake: 0.7065 LossD_Real: 0.7018  LossG_Adv: 0.6801 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[28](6/7): Loss_D: 0.7051 Loss_G: 0.6783 LossD_Fake: 0.7083 LossD_Real: 0.7019  LossG_Adv: 0.6783 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_28_07.jpg - learning rate: 0.0001
# ===> Epoch[28](7/7): Loss_D: 0.7056 Loss_G: 0.6770 LossD_Fake: 0.7097 LossD_Real: 0.7016  LossG_Adv: 0.6770 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[29](1/7): Loss_D: 0.7063 Loss_G: 0.6805 LossD_Fake: 0.7103 LossD_Real: 0.7022  LossG_Adv: 0.6805 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[29](2/7): Loss_D: 0.7037 Loss_G: 0.6796 LossD_Fake: 0.7070 LossD_Real: 0.7004  LossG_Adv: 0.6796 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[29](3/7): Loss_D: 0.7042 Loss_G: 0.6785 LossD_Fake: 0.7081 LossD_Real: 0.7004  LossG_Adv: 0.6785 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[29](4/7): Loss_D: 0.7051 Loss_G: 0.6770 LossD_Fake: 0.7096 LossD_Real: 0.7005  LossG_Adv: 0.6770 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[29](5/7): Loss_D: 0.7056 Loss_G: 0.6758 LossD_Fake: 0.7109 LossD_Real: 0.7003  LossG_Adv: 0.6758 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[29](6/7): Loss_D: 0.7058 Loss_G: 0.6752 LossD_Fake: 0.7115 LossD_Real: 0.7002  LossG_Adv: 0.6752 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_29_07.jpg - learning rate: 0.0001
# ===> Epoch[29](7/7): Loss_D: 0.7063 Loss_G: 0.6748 LossD_Fake: 0.7119 LossD_Real: 0.7006  LossG_Adv: 0.6748 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[30](1/7): Loss_D: 0.7062 Loss_G: 0.6797 LossD_Fake: 0.7119 LossD_Real: 0.7004  LossG_Adv: 0.6797 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[30](2/7): Loss_D: 0.7035 Loss_G: 0.6786 LossD_Fake: 0.7080 LossD_Real: 0.6991  LossG_Adv: 0.6786 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[30](3/7): Loss_D: 0.7039 Loss_G: 0.6779 LossD_Fake: 0.7087 LossD_Real: 0.6990  LossG_Adv: 0.6779 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[30](4/7): Loss_D: 0.7043 Loss_G: 0.6775 LossD_Fake: 0.7091 LossD_Real: 0.6994  LossG_Adv: 0.6775 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[30](5/7): Loss_D: 0.7043 Loss_G: 0.6769 LossD_Fake: 0.7098 LossD_Real: 0.6989  LossG_Adv: 0.6769 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[30](6/7): Loss_D: 0.7043 Loss_G: 0.6770 LossD_Fake: 0.7097 LossD_Real: 0.6990  LossG_Adv: 0.6770 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_30_07.jpg - learning rate: 0.0001
# ===> Epoch[30](7/7): Loss_D: 0.7044 Loss_G: 0.6771 LossD_Fake: 0.7095 LossD_Real: 0.6992  LossG_Adv: 0.6771 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[31](1/7): Loss_D: 0.7046 Loss_G: 0.6815 LossD_Fake: 0.7102 LossD_Real: 0.6991  LossG_Adv: 0.6815 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[31](2/7): Loss_D: 0.7023 Loss_G: 0.6803 LossD_Fake: 0.7063 LossD_Real: 0.6983  LossG_Adv: 0.6803 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[31](3/7): Loss_D: 0.7026 Loss_G: 0.6797 LossD_Fake: 0.7069 LossD_Real: 0.6982  LossG_Adv: 0.6797 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[31](4/7): Loss_D: 0.7030 Loss_G: 0.6792 LossD_Fake: 0.7074 LossD_Real: 0.6986  LossG_Adv: 0.6792 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[31](5/7): Loss_D: 0.7031 Loss_G: 0.6786 LossD_Fake: 0.7081 LossD_Real: 0.6981  LossG_Adv: 0.6786 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[31](6/7): Loss_D: 0.7033 Loss_G: 0.6783 LossD_Fake: 0.7084 LossD_Real: 0.6982  LossG_Adv: 0.6783 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_31_07.jpg - learning rate: 0.0001
# ===> Epoch[31](7/7): Loss_D: 0.7034 Loss_G: 0.6778 LossD_Fake: 0.7088 LossD_Real: 0.6980  LossG_Adv: 0.6778 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[32](1/7): Loss_D: 0.7036 Loss_G: 0.6811 LossD_Fake: 0.7089 LossD_Real: 0.6982  LossG_Adv: 0.6811 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[32](2/7): Loss_D: 0.7018 Loss_G: 0.6801 LossD_Fake: 0.7065 LossD_Real: 0.6972  LossG_Adv: 0.6801 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[32](3/7): Loss_D: 0.7023 Loss_G: 0.6792 LossD_Fake: 0.7074 LossD_Real: 0.6971  LossG_Adv: 0.6792 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[32](4/7): Loss_D: 0.7029 Loss_G: 0.6781 LossD_Fake: 0.7086 LossD_Real: 0.6971  LossG_Adv: 0.6781 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[32](5/7): Loss_D: 0.7029 Loss_G: 0.6775 LossD_Fake: 0.7091 LossD_Real: 0.6968  LossG_Adv: 0.6775 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[32](6/7): Loss_D: 0.7034 Loss_G: 0.6771 LossD_Fake: 0.7096 LossD_Real: 0.6972  LossG_Adv: 0.6771 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_32_07.jpg - learning rate: 0.0001
# ===> Epoch[32](7/7): Loss_D: 0.7039 Loss_G: 0.6763 LossD_Fake: 0.7104 LossD_Real: 0.6974  LossG_Adv: 0.6763 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[33](1/7): Loss_D: 0.7044 Loss_G: 0.6791 LossD_Fake: 0.7116 LossD_Real: 0.6971  LossG_Adv: 0.6791 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[33](2/7): Loss_D: 0.7034 Loss_G: 0.6773 LossD_Fake: 0.7094 LossD_Real: 0.6974  LossG_Adv: 0.6773 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[33](3/7): Loss_D: 0.7038 Loss_G: 0.6758 LossD_Fake: 0.7110 LossD_Real: 0.6967  LossG_Adv: 0.6758 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[33](4/7): Loss_D: 0.7042 Loss_G: 0.6749 LossD_Fake: 0.7118 LossD_Real: 0.6967  LossG_Adv: 0.6749 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[33](5/7): Loss_D: 0.7052 Loss_G: 0.6738 LossD_Fake: 0.7131 LossD_Real: 0.6973  LossG_Adv: 0.6738 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[33](6/7): Loss_D: 0.7054 Loss_G: 0.6728 LossD_Fake: 0.7140 LossD_Real: 0.6969  LossG_Adv: 0.6728 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_33_07.jpg - learning rate: 0.0001
# ===> Epoch[33](7/7): Loss_D: 0.7064 Loss_G: 0.6710 LossD_Fake: 0.7159 LossD_Real: 0.6970  LossG_Adv: 0.6710 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[34](1/7): Loss_D: 0.7067 Loss_G: 0.6751 LossD_Fake: 0.7167 LossD_Real: 0.6967  LossG_Adv: 0.6751 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[34](2/7): Loss_D: 0.7053 Loss_G: 0.6742 LossD_Fake: 0.7126 LossD_Real: 0.6981  LossG_Adv: 0.6742 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[34](3/7): Loss_D: 0.7056 Loss_G: 0.6736 LossD_Fake: 0.7132 LossD_Real: 0.6979  LossG_Adv: 0.6736 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[34](4/7): Loss_D: 0.7062 Loss_G: 0.6722 LossD_Fake: 0.7147 LossD_Real: 0.6977  LossG_Adv: 0.6722 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[34](5/7): Loss_D: 0.7065 Loss_G: 0.6718 LossD_Fake: 0.7150 LossD_Real: 0.6979  LossG_Adv: 0.6718 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[34](6/7): Loss_D: 0.7071 Loss_G: 0.6702 LossD_Fake: 0.7167 LossD_Real: 0.6975  LossG_Adv: 0.6702 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_34_07.jpg - learning rate: 0.0001
# ===> Epoch[34](7/7): Loss_D: 0.7079 Loss_G: 0.6684 LossD_Fake: 0.7187 LossD_Real: 0.6972  LossG_Adv: 0.6684 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[35](1/7): Loss_D: 0.7076 Loss_G: 0.6758 LossD_Fake: 0.7184 LossD_Real: 0.6968  LossG_Adv: 0.6758 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[35](2/7): Loss_D: 0.7057 Loss_G: 0.6750 LossD_Fake: 0.7117 LossD_Real: 0.6997  LossG_Adv: 0.6750 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[35](3/7): Loss_D: 0.7061 Loss_G: 0.6737 LossD_Fake: 0.7131 LossD_Real: 0.6992  LossG_Adv: 0.6737 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[35](4/7): Loss_D: 0.7068 Loss_G: 0.6724 LossD_Fake: 0.7145 LossD_Real: 0.6992  LossG_Adv: 0.6724 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[35](5/7): Loss_D: 0.7070 Loss_G: 0.6720 LossD_Fake: 0.7149 LossD_Real: 0.6992  LossG_Adv: 0.6720 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[35](6/7): Loss_D: 0.7072 Loss_G: 0.6710 LossD_Fake: 0.7159 LossD_Real: 0.6985  LossG_Adv: 0.6710 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_35_07.jpg - learning rate: 0.0001
# ===> Epoch[35](7/7): Loss_D: 0.7078 Loss_G: 0.6699 LossD_Fake: 0.7170 LossD_Real: 0.6987  LossG_Adv: 0.6699 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[36](1/7): Loss_D: 0.7074 Loss_G: 0.6790 LossD_Fake: 0.7162 LossD_Real: 0.6986  LossG_Adv: 0.6790 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[36](2/7): Loss_D: 0.7044 Loss_G: 0.6782 LossD_Fake: 0.7084 LossD_Real: 0.7004  LossG_Adv: 0.6782 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[36](3/7): Loss_D: 0.7047 Loss_G: 0.6771 LossD_Fake: 0.7096 LossD_Real: 0.6999  LossG_Adv: 0.6771 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[36](4/7): Loss_D: 0.7050 Loss_G: 0.6768 LossD_Fake: 0.7098 LossD_Real: 0.7001  LossG_Adv: 0.6768 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[36](5/7): Loss_D: 0.7055 Loss_G: 0.6763 LossD_Fake: 0.7104 LossD_Real: 0.7005  LossG_Adv: 0.6763 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[36](6/7): Loss_D: 0.7056 Loss_G: 0.6762 LossD_Fake: 0.7105 LossD_Real: 0.7007  LossG_Adv: 0.6762 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_36_07.jpg - learning rate: 0.0001
# ===> Epoch[36](7/7): Loss_D: 0.7059 Loss_G: 0.6757 LossD_Fake: 0.7110 LossD_Real: 0.7009  LossG_Adv: 0.6757 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[37](1/7): Loss_D: 0.7061 Loss_G: 0.6810 LossD_Fake: 0.7117 LossD_Real: 0.7005  LossG_Adv: 0.6810 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[37](2/7): Loss_D: 0.7035 Loss_G: 0.6798 LossD_Fake: 0.7068 LossD_Real: 0.7001  LossG_Adv: 0.6798 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[37](3/7): Loss_D: 0.7040 Loss_G: 0.6785 LossD_Fake: 0.7081 LossD_Real: 0.6999  LossG_Adv: 0.6785 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[37](4/7): Loss_D: 0.7040 Loss_G: 0.6785 LossD_Fake: 0.7081 LossD_Real: 0.7000  LossG_Adv: 0.6785 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[37](5/7): Loss_D: 0.7043 Loss_G: 0.6781 LossD_Fake: 0.7085 LossD_Real: 0.7000  LossG_Adv: 0.6781 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[37](6/7): Loss_D: 0.7052 Loss_G: 0.6768 LossD_Fake: 0.7098 LossD_Real: 0.7005  LossG_Adv: 0.6768 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_37_07.jpg - learning rate: 0.0001
# ===> Epoch[37](7/7): Loss_D: 0.7054 Loss_G: 0.6750 LossD_Fake: 0.7117 LossD_Real: 0.6992  LossG_Adv: 0.6750 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[38](1/7): Loss_D: 0.7057 Loss_G: 0.6804 LossD_Fake: 0.7114 LossD_Real: 0.6999  LossG_Adv: 0.6804 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[38](2/7): Loss_D: 0.7032 Loss_G: 0.6805 LossD_Fake: 0.7061 LossD_Real: 0.7003  LossG_Adv: 0.6805 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[38](3/7): Loss_D: 0.7037 Loss_G: 0.6789 LossD_Fake: 0.7076 LossD_Real: 0.6997  LossG_Adv: 0.6789 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[38](4/7): Loss_D: 0.7041 Loss_G: 0.6787 LossD_Fake: 0.7079 LossD_Real: 0.7003  LossG_Adv: 0.6787 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[38](5/7): Loss_D: 0.7040 Loss_G: 0.6784 LossD_Fake: 0.7082 LossD_Real: 0.6999  LossG_Adv: 0.6784 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[38](6/7): Loss_D: 0.7042 Loss_G: 0.6781 LossD_Fake: 0.7085 LossD_Real: 0.6999  LossG_Adv: 0.6781 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_38_07.jpg - learning rate: 0.0001
# ===> Epoch[38](7/7): Loss_D: 0.7044 Loss_G: 0.6776 LossD_Fake: 0.7090 LossD_Real: 0.6997  LossG_Adv: 0.6776 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[39](1/7): Loss_D: 0.7044 Loss_G: 0.6822 LossD_Fake: 0.7087 LossD_Real: 0.7001  LossG_Adv: 0.6822 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[39](2/7): Loss_D: 0.7025 Loss_G: 0.6815 LossD_Fake: 0.7050 LossD_Real: 0.7000  LossG_Adv: 0.6815 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[39](3/7): Loss_D: 0.7029 Loss_G: 0.6803 LossD_Fake: 0.7062 LossD_Real: 0.6995  LossG_Adv: 0.6803 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ...
# ===> Epoch[68](3/7): Loss_D: 0.7002 Loss_G: 0.6863 LossD_Fake: 0.7002 LossD_Real: 0.7002  LossG_Adv: 0.6863 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[68](4/7): Loss_D: 0.7001 Loss_G: 0.6857 LossD_Fake: 0.7007 LossD_Real: 0.6995  LossG_Adv: 0.6857 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[68](5/7): Loss_D: 0.7004 Loss_G: 0.6855 LossD_Fake: 0.7010 LossD_Real: 0.6998  LossG_Adv: 0.6855 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[68](6/7): Loss_D: 0.7006 Loss_G: 0.6849 LossD_Fake: 0.7015 LossD_Real: 0.6998  LossG_Adv: 0.6849 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_68_07.jpg - learning rate: 0.0001
# ===> Epoch[68](7/7): Loss_D: 0.7012 Loss_G: 0.6840 LossD_Fake: 0.7025 LossD_Real: 0.7000  LossG_Adv: 0.6840 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[69](1/7): Loss_D: 0.7012 Loss_G: 0.6853 LossD_Fake: 0.7027 LossD_Real: 0.6996  LossG_Adv: 0.6853 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[69](2/7): Loss_D: 0.7000 Loss_G: 0.6844 LossD_Fake: 0.7021 LossD_Real: 0.6979  LossG_Adv: 0.6844 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[69](3/7): Loss_D: 0.7001 Loss_G: 0.6839 LossD_Fake: 0.7026 LossD_Real: 0.6976  LossG_Adv: 0.6839 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[69](4/7): Loss_D: 0.7007 Loss_G: 0.6836 LossD_Fake: 0.7029 LossD_Real: 0.6986  LossG_Adv: 0.6836 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[69](5/7): Loss_D: 0.7007 Loss_G: 0.6834 LossD_Fake: 0.7031 LossD_Real: 0.6983  LossG_Adv: 0.6834 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[69](6/7): Loss_D: 0.7010 Loss_G: 0.6828 LossD_Fake: 0.7037 LossD_Real: 0.6983  LossG_Adv: 0.6828 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_69_07.jpg - learning rate: 0.0001
# ===> Epoch[69](7/7): Loss_D: 0.7016 Loss_G: 0.6826 LossD_Fake: 0.7039 LossD_Real: 0.6992  LossG_Adv: 0.6826 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[70](1/7): Loss_D: 0.7012 Loss_G: 0.6840 LossD_Fake: 0.7047 LossD_Real: 0.6976  LossG_Adv: 0.6840 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[70](2/7): Loss_D: 0.6998 Loss_G: 0.6833 LossD_Fake: 0.7032 LossD_Real: 0.6963  LossG_Adv: 0.6833 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[70](3/7): Loss_D: 0.7001 Loss_G: 0.6834 LossD_Fake: 0.7031 LossD_Real: 0.6970  LossG_Adv: 0.6834 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[70](4/7): Loss_D: 0.6999 Loss_G: 0.6834 LossD_Fake: 0.7031 LossD_Real: 0.6967  LossG_Adv: 0.6834 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[70](5/7): Loss_D: 0.7000 Loss_G: 0.6830 LossD_Fake: 0.7035 LossD_Real: 0.6965  LossG_Adv: 0.6830 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[70](6/7): Loss_D: 0.7004 Loss_G: 0.6825 LossD_Fake: 0.7040 LossD_Real: 0.6969  LossG_Adv: 0.6825 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_70_07.jpg - learning rate: 0.0001
# ===> Epoch[70](7/7): Loss_D: 0.7006 Loss_G: 0.6822 LossD_Fake: 0.7043 LossD_Real: 0.6970  LossG_Adv: 0.6822 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[71](1/7): Loss_D: 0.7007 Loss_G: 0.6836 LossD_Fake: 0.7046 LossD_Real: 0.6969  LossG_Adv: 0.6836 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[71](2/7): Loss_D: 0.6992 Loss_G: 0.6832 LossD_Fake: 0.7033 LossD_Real: 0.6952  LossG_Adv: 0.6832 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[71](3/7): Loss_D: 0.6993 Loss_G: 0.6827 LossD_Fake: 0.7038 LossD_Real: 0.6948  LossG_Adv: 0.6827 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[71](4/7): Loss_D: 0.6993 Loss_G: 0.6830 LossD_Fake: 0.7035 LossD_Real: 0.6952  LossG_Adv: 0.6830 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[71](5/7): Loss_D: 0.6993 Loss_G: 0.6828 LossD_Fake: 0.7037 LossD_Real: 0.6950  LossG_Adv: 0.6828 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[71](6/7): Loss_D: 0.6992 Loss_G: 0.6828 LossD_Fake: 0.7037 LossD_Real: 0.6946  LossG_Adv: 0.6828 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_71_07.jpg - learning rate: 0.0001
# ===> Epoch[71](7/7): Loss_D: 0.6993 Loss_G: 0.6829 LossD_Fake: 0.7037 LossD_Real: 0.6950  LossG_Adv: 0.6829 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[72](1/7): Loss_D: 0.6992 Loss_G: 0.6840 LossD_Fake: 0.7037 LossD_Real: 0.6947  LossG_Adv: 0.6840 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[72](2/7): Loss_D: 0.6978 Loss_G: 0.6837 LossD_Fake: 0.7028 LossD_Real: 0.6929  LossG_Adv: 0.6837 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[72](3/7): Loss_D: 0.6983 Loss_G: 0.6829 LossD_Fake: 0.7036 LossD_Real: 0.6930  LossG_Adv: 0.6829 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[72](4/7): Loss_D: 0.6986 Loss_G: 0.6831 LossD_Fake: 0.7034 LossD_Real: 0.6937  LossG_Adv: 0.6831 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[72](5/7): Loss_D: 0.6988 Loss_G: 0.6827 LossD_Fake: 0.7039 LossD_Real: 0.6937  LossG_Adv: 0.6827 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[72](6/7): Loss_D: 0.6990 Loss_G: 0.6821 LossD_Fake: 0.7044 LossD_Real: 0.6935  LossG_Adv: 0.6821 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_72_07.jpg - learning rate: 0.0001
# ===> Epoch[72](7/7): Loss_D: 0.6990 Loss_G: 0.6822 LossD_Fake: 0.7043 LossD_Real: 0.6936  LossG_Adv: 0.6822 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[73](1/7): Loss_D: 0.6991 Loss_G: 0.6827 LossD_Fake: 0.7048 LossD_Real: 0.6934  LossG_Adv: 0.6827 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[73](2/7): Loss_D: 0.6985 Loss_G: 0.6817 LossD_Fake: 0.7049 LossD_Real: 0.6921  LossG_Adv: 0.6817 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[73](3/7): Loss_D: 0.6988 Loss_G: 0.6812 LossD_Fake: 0.7053 LossD_Real: 0.6923  LossG_Adv: 0.6812 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[73](4/7): Loss_D: 0.6995 Loss_G: 0.6804 LossD_Fake: 0.7062 LossD_Real: 0.6928  LossG_Adv: 0.6804 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[73](5/7): Loss_D: 0.6997 Loss_G: 0.6798 LossD_Fake: 0.7068 LossD_Real: 0.6925  LossG_Adv: 0.6798 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[73](6/7): Loss_D: 0.7004 Loss_G: 0.6787 LossD_Fake: 0.7079 LossD_Real: 0.6929  LossG_Adv: 0.6787 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_73_07.jpg - learning rate: 0.0001
# ===> Epoch[73](7/7): Loss_D: 0.7017 Loss_G: 0.6766 LossD_Fake: 0.7101 LossD_Real: 0.6933  LossG_Adv: 0.6766 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[74](1/7): Loss_D: 0.7021 Loss_G: 0.6802 LossD_Fake: 0.7116 LossD_Real: 0.6926  LossG_Adv: 0.6802 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[74](2/7): Loss_D: 0.7010 Loss_G: 0.6790 LossD_Fake: 0.7075 LossD_Real: 0.6945  LossG_Adv: 0.6790 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[74](3/7): Loss_D: 0.7020 Loss_G: 0.6781 LossD_Fake: 0.7085 LossD_Real: 0.6954  LossG_Adv: 0.6781 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[74](4/7): Loss_D: 0.7020 Loss_G: 0.6779 LossD_Fake: 0.7087 LossD_Real: 0.6952  LossG_Adv: 0.6779 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[74](5/7): Loss_D: 0.7019 Loss_G: 0.6773 LossD_Fake: 0.7094 LossD_Real: 0.6944  LossG_Adv: 0.6773 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[74](6/7): Loss_D: 0.7022 Loss_G: 0.6769 LossD_Fake: 0.7097 LossD_Real: 0.6947  LossG_Adv: 0.6769 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_74_07.jpg - learning rate: 0.0001
# ===> Epoch[74](7/7): Loss_D: 0.7021 Loss_G: 0.6762 LossD_Fake: 0.7105 LossD_Real: 0.6937  LossG_Adv: 0.6762 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[75](1/7): Loss_D: 0.7027 Loss_G: 0.6831 LossD_Fake: 0.7105 LossD_Real: 0.6948  LossG_Adv: 0.6831 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[75](2/7): Loss_D: 0.7008 Loss_G: 0.6822 LossD_Fake: 0.7043 LossD_Real: 0.6972  LossG_Adv: 0.6822 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[75](3/7): Loss_D: 0.7012 Loss_G: 0.6822 LossD_Fake: 0.7043 LossD_Real: 0.6981  LossG_Adv: 0.6822 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[75](4/7): Loss_D: 0.7011 Loss_G: 0.6822 LossD_Fake: 0.7043 LossD_Real: 0.6978  LossG_Adv: 0.6822 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[75](5/7): Loss_D: 0.7014 Loss_G: 0.6817 LossD_Fake: 0.7048 LossD_Real: 0.6979  LossG_Adv: 0.6817 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[75](6/7): Loss_D: 0.7014 Loss_G: 0.6813 LossD_Fake: 0.7053 LossD_Real: 0.6975  LossG_Adv: 0.6813 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_75_07.jpg - learning rate: 0.0001
# ===> Epoch[75](7/7): Loss_D: 0.7009 Loss_G: 0.6819 LossD_Fake: 0.7046 LossD_Real: 0.6973  LossG_Adv: 0.6819 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[76](1/7): Loss_D: 0.7011 Loss_G: 0.6874 LossD_Fake: 0.7045 LossD_Real: 0.6976  LossG_Adv: 0.6874 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[76](2/7): Loss_D: 0.6999 Loss_G: 0.6867 LossD_Fake: 0.6998 LossD_Real: 0.7001  LossG_Adv: 0.6867 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[76](3/7): Loss_D: 0.7000 Loss_G: 0.6860 LossD_Fake: 0.7004 LossD_Real: 0.6996  LossG_Adv: 0.6860 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[76](4/7): Loss_D: 0.7001 Loss_G: 0.6860 LossD_Fake: 0.7004 LossD_Real: 0.6997  LossG_Adv: 0.6860 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[76](5/7): Loss_D: 0.7002 Loss_G: 0.6860 LossD_Fake: 0.7004 LossD_Real: 0.6999  LossG_Adv: 0.6860 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[76](6/7): Loss_D: 0.7003 Loss_G: 0.6862 LossD_Fake: 0.7003 LossD_Real: 0.7003  LossG_Adv: 0.6862 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_76_07.jpg - learning rate: 0.0001
# ===> Epoch[76](7/7): Loss_D: 0.7000 Loss_G: 0.6864 LossD_Fake: 0.7000 LossD_Real: 0.6999  LossG_Adv: 0.6864 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[77](1/7): Loss_D: 0.7003 Loss_G: 0.6894 LossD_Fake: 0.7010 LossD_Real: 0.6997  LossG_Adv: 0.6894 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[77](2/7): Loss_D: 0.6993 Loss_G: 0.6891 LossD_Fake: 0.6974 LossD_Real: 0.7011  LossG_Adv: 0.6891 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[77](3/7): Loss_D: 0.6995 Loss_G: 0.6892 LossD_Fake: 0.6973 LossD_Real: 0.7018  LossG_Adv: 0.6892 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[77](4/7): Loss_D: 0.6996 Loss_G: 0.6891 LossD_Fake: 0.6974 LossD_Real: 0.7018  LossG_Adv: 0.6891 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[77](5/7): Loss_D: 0.6996 Loss_G: 0.6887 LossD_Fake: 0.6977 LossD_Real: 0.7014  LossG_Adv: 0.6887 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[77](6/7): Loss_D: 0.6993 Loss_G: 0.6892 LossD_Fake: 0.6973 LossD_Real: 0.7013  LossG_Adv: 0.6892 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_77_07.jpg - learning rate: 0.0001
# ===> Epoch[77](7/7): Loss_D: 0.6997 Loss_G: 0.6886 LossD_Fake: 0.6978 LossD_Real: 0.7016  LossG_Adv: 0.6886 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[78](1/7): Loss_D: 0.6996 Loss_G: 0.6910 LossD_Fake: 0.6974 LossD_Real: 0.7018  LossG_Adv: 0.6910 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[78](2/7): Loss_D: 0.6989 Loss_G: 0.6906 LossD_Fake: 0.6959 LossD_Real: 0.7019  LossG_Adv: 0.6906 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[78](3/7): Loss_D: 0.6988 Loss_G: 0.6903 LossD_Fake: 0.6961 LossD_Real: 0.7015  LossG_Adv: 0.6903 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[78](4/7): Loss_D: 0.6990 Loss_G: 0.6902 LossD_Fake: 0.6963 LossD_Real: 0.7018  LossG_Adv: 0.6902 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[78](5/7): Loss_D: 0.6992 Loss_G: 0.6901 LossD_Fake: 0.6964 LossD_Real: 0.7019  LossG_Adv: 0.6901 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[78](6/7): Loss_D: 0.6991 Loss_G: 0.6901 LossD_Fake: 0.6963 LossD_Real: 0.7020  LossG_Adv: 0.6901 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_78_07.jpg - learning rate: 0.0001
# ===> Epoch[78](7/7): Loss_D: 0.6992 Loss_G: 0.6897 LossD_Fake: 0.6967 LossD_Real: 0.7016  LossG_Adv: 0.6897 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[79](1/7): Loss_D: 0.6991 Loss_G: 0.6919 LossD_Fake: 0.6967 LossD_Real: 0.7015  LossG_Adv: 0.6919 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[79](2/7): Loss_D: 0.6986 Loss_G: 0.6919 LossD_Fake: 0.6945 LossD_Real: 0.7027  LossG_Adv: 0.6919 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[79](3/7): Loss_D: 0.6990 Loss_G: 0.6917 LossD_Fake: 0.6947 LossD_Real: 0.7032  LossG_Adv: 0.6917 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[79](4/7): Loss_D: 0.6989 Loss_G: 0.6917 LossD_Fake: 0.6948 LossD_Real: 0.7031  LossG_Adv: 0.6917 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[79](5/7): Loss_D: 0.6991 Loss_G: 0.6912 LossD_Fake: 0.6952 LossD_Real: 0.7031  LossG_Adv: 0.6912 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[79](6/7): Loss_D: 0.6991 Loss_G: 0.6911 LossD_Fake: 0.6954 LossD_Real: 0.7029  LossG_Adv: 0.6911 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_79_07.jpg - learning rate: 0.0001
# ===> Epoch[79](7/7): Loss_D: 0.6990 Loss_G: 0.6911 LossD_Fake: 0.6953 LossD_Real: 0.7028  LossG_Adv: 0.6911 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset
# ===> Epoch[80](1/7): Loss_D: 0.6993 Loss_G: 0.6918 LossD_Fake: 0.6954 LossD_Real: 0.7033  LossG_Adv: 0.6918 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[80](2/7): Loss_D: 0.6989 Loss_G: 0.6914 LossD_Fake: 0.6950 LossD_Real: 0.7028  LossG_Adv: 0.6914 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[80](3/7): Loss_D: 0.6992 Loss_G: 0.6914 LossD_Fake: 0.6951 LossD_Real: 0.7033  LossG_Adv: 0.6914 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[80](4/7): Loss_D: 0.6989 Loss_G: 0.6909 LossD_Fake: 0.6956 LossD_Real: 0.7023  LossG_Adv: 0.6909 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[80](5/7): Loss_D: 0.6990 Loss_G: 0.6907 LossD_Fake: 0.6957 LossD_Real: 0.7024  LossG_Adv: 0.6907 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# ===> Epoch[80](6/7): Loss_D: 0.6992 Loss_G: 0.6909 LossD_Fake: 0.6956 LossD_Real: 0.7028  LossG_Adv: 0.6909 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
#
# saving sample dataset_80_07.jpg - learning rate: 0.0001
# ===> Epoch[80](7/7): Loss_D: 0.6992 Loss_G: 0.6902 LossD_Fake: 0.6962 LossD_Real: 0.7022  LossG_Adv: 0.6902 LossG_L1: 0.0000 LossG_Style 0.0000 LossG_Content 0.0000
# Checkpoint saved to checkpointdataset

# %%
def run():
    torch.multiprocessing.freeze_support()
    print('loop')

# %%
if __name__ == '__main__':
    run()
# Out:
# loop
